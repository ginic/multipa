# %% [markdown]
# # Upload experimental models to Hugging Face Model repositories
# This notebook is a helper for uploading pre-trained models to Hugging Face. It allows you to add README info for experiments at upload time for better documentation.

# %%
from huggingface_hub import HfApi
import transformers

from pathlib import Path

# %%
# Model name prefix to 
MODEL_ROOT = Path("../data/models/")
ALL_MODELS_README = """
---
license: mit
language:
- en
pipeline_tag: automatic-speech-recognition
---
# About 
This model was created to support experiments for evaluating phonetic transcription 
with the Buckeye corpus as part of https://github.com/ginic/multipa/tree/buckeye_experiments. 
This is a version of facebook/wav2vec2-large-xlsr-53 fine tuned on a very specific subset of the Buckeye corpus.
For details about specific model parameters, please view the config.json here or 
training scripts in scripts/buckeye_experiments on the `buckeye_experiments` branch of the GitHub repository. 

# Experiment Details
"""

# Specific sets of experiments have more details. I just copied these from the EXPERIMENT_LOG.md 
README_MAPPINGS = {
    # This was the best hyperparam tuned model & these model parameters were used for all other experiments
    "hyperparam_tuning_1":"""Vary the random seed to select training data while keeping an even 50/50 gender split to measure statistical significance of changing training data selection. Retrain with the same model parameters, but different data seeding to measure statistical significance of data seed, keeping 50/50 gender split. 

Goals: 
- Establish whether data variation with the same gender makeup is statistically significant in changing performance on the test set

Params to vary:
- training data seed (--train_seed): [7 (default), 91, 15, 139, 503]
""",
    "data_seed": """Vary the random seed to select training data while keeping an even 50/50 gender split to measure statistical significance of changing training data selection. Retrain with the same model parameters, but different data seeding to measure statistical significance of data seed, keeping 50/50 gender split. 

Goals: 
- Establish whether data variation with the same gender makeup is statistically significant in changing performance on the test set

Params to vary:
- training data seed (--train_seed): [7 (default), 91, 15, 139, 503]
""",
"gender_split": """Still training with a total amount of data equal to half the full training data (4000 examples), vary the gender split 30/70, but draw examples from all individuals. Do 5 models for each gender split with the same model parameters but different data seeds. 

Goals: 
- Determine how different in gender split in training data affects performance

Params to vary: 
- percent female (--percent_female) [0.3, 0.7]
- training seed (--train_seed): [359, 130, 809, 700, 114]""", 
}

# %%
api = HfApi()
for model_folder in MODEL_ROOT.iterdir():
    if model_folder.is_dir(): 
        for prefix in README_MAPPINGS.keys(): 
            if model_folder.name.startswith(prefix):
                print(f"Model {model_folder} matches prefix '{prefix}'.")
                full_readme = "".join([ALL_MODELS_README, README_MAPPINGS[prefix]])
                model_to_upload = model_folder / "wav2vec2-large-xlsr-buckeye-ipa"
                readme_path = model_to_upload / "README.md"
                readme_path.write_text(full_readme)

                model_pipeline = transformers.pipeline("automatic-speech-recognition", model=model_to_upload)

                hub_name = f"ginic/{model_folder.name}_wav2vec2-large-xlsr-buckeye-ipa" 
                print("Uploading to hub as:", hub_name)
                model_pipeline.push_to_hub(hub_name)
                #help(model_pipeline.push_to_hub)
                print("Uploading README for", hub_name)
                api.upload_file(
                    path_or_fileobj = readme_path, 
                    path_in_repo = "README.md",
                    repo_id = hub_name, 
                    repo_type = "model"
                )
                break
# Out:
# Model ../data/models/data_seed_1 matches prefix 'data_seed'.
# Some weights of the model checkpoint at ../data/models/data_seed_1/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/data_seed_1/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/data_seed_1_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/data_seed_1_wav2vec2-large-xlsr-buckeye-ipa
# Model ../data/models/data_seed_2 matches prefix 'data_seed'.
# Some weights of the model checkpoint at ../data/models/data_seed_2/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/data_seed_2/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/data_seed_2_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/data_seed_2_wav2vec2-large-xlsr-buckeye-ipa
# Model ../data/models/data_seed_3 matches prefix 'data_seed'.
# Some weights of the model checkpoint at ../data/models/data_seed_3/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/data_seed_3/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/data_seed_3_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/data_seed_3_wav2vec2-large-xlsr-buckeye-ipa
# Model ../data/models/data_seed_4 matches prefix 'data_seed'.
# Some weights of the model checkpoint at ../data/models/data_seed_4/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/data_seed_4/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/data_seed_4_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/data_seed_4_wav2vec2-large-xlsr-buckeye-ipa
# Model ../data/models/gender_split_30_female_1 matches prefix 'gender_split'.
# Some weights of the model checkpoint at ../data/models/gender_split_30_female_1/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/gender_split_30_female_1/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/gender_split_30_female_1_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/gender_split_30_female_1_wav2vec2-large-xlsr-buckeye-ipa
# Model ../data/models/gender_split_30_female_2 matches prefix 'gender_split'.
# Some weights of the model checkpoint at ../data/models/gender_split_30_female_2/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/gender_split_30_female_2/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/gender_split_30_female_2_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/gender_split_30_female_2_wav2vec2-large-xlsr-buckeye-ipa
# Model ../data/models/gender_split_30_female_3 matches prefix 'gender_split'.
# Some weights of the model checkpoint at ../data/models/gender_split_30_female_3/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/gender_split_30_female_3/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/gender_split_30_female_3_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/gender_split_30_female_3_wav2vec2-large-xlsr-buckeye-ipa
# Model ../data/models/gender_split_30_female_4 matches prefix 'gender_split'.
# Some weights of the model checkpoint at ../data/models/gender_split_30_female_4/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/gender_split_30_female_4/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/gender_split_30_female_4_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/gender_split_30_female_4_wav2vec2-large-xlsr-buckeye-ipa
# Model ../data/models/gender_split_30_female_5 matches prefix 'gender_split'.
# Some weights of the model checkpoint at ../data/models/gender_split_30_female_5/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/gender_split_30_female_5/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/gender_split_30_female_5_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/gender_split_30_female_5_wav2vec2-large-xlsr-buckeye-ipa
# Model ../data/models/gender_split_70_female_1 matches prefix 'gender_split'.
# Some weights of the model checkpoint at ../data/models/gender_split_70_female_1/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/gender_split_70_female_1/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/gender_split_70_female_1_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/gender_split_70_female_1_wav2vec2-large-xlsr-buckeye-ipa
# Model ../data/models/gender_split_70_female_2 matches prefix 'gender_split'.
# Some weights of the model checkpoint at ../data/models/gender_split_70_female_2/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/gender_split_70_female_2/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/gender_split_70_female_2_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/gender_split_70_female_2_wav2vec2-large-xlsr-buckeye-ipa
# Model ../data/models/gender_split_70_female_3 matches prefix 'gender_split'.
# Some weights of the model checkpoint at ../data/models/gender_split_70_female_3/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/gender_split_70_female_3/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/gender_split_70_female_3_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/gender_split_70_female_3_wav2vec2-large-xlsr-buckeye-ipa
# Model ../data/models/gender_split_70_female_4 matches prefix 'gender_split'.
# Some weights of the model checkpoint at ../data/models/gender_split_70_female_4/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/gender_split_70_female_4/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/gender_split_70_female_4_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/gender_split_70_female_4_wav2vec2-large-xlsr-buckeye-ipa
# Model ../data/models/gender_split_70_female_5 matches prefix 'gender_split'.
# Some weights of the model checkpoint at ../data/models/gender_split_70_female_5/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/gender_split_70_female_5/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/gender_split_70_female_5_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/gender_split_70_female_5_wav2vec2-large-xlsr-buckeye-ipa
# Model ../data/models/hyperparam_tuning_1 matches prefix 'hyperparam_tuning_1'.
# Some weights of the model checkpoint at ../data/models/hyperparam_tuning_1/wav2vec2-large-xlsr-buckeye-ipa were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at ../data/models/hyperparam_tuning_1/wav2vec2-large-xlsr-buckeye-ipa and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Uploading to hub as: ginic/hyperparam_tuning_1_wav2vec2-large-xlsr-buckeye-ipa
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Uploading README for ginic/hyperparam_tuning_1_wav2vec2-large-xlsr-buckeye-ipa

# %%
# Sanity check that upload worked and the model from the hub can be used for inference
from multipa.data_utils import load_buckeye_split
import datasets

dataset = datasets.load_dataset("MLCommons/peoples_speech", split="train", streaming=True).take(2)
dataset = dataset.cast_column("audio", datasets.Audio(sampling_rate=16_000))
print(list(dataset))
pipe = transformers.pipeline("automatic-speech-recognition", model="ginic/data_seed_1_wav2vec2-large-xlsr-buckeye-ipa")
for i in list(dataset): 
    pred = pipe(i["audio"])
    print("actual text:", i["text"])
    print("prediction:", pred)
# Out:
# No config specified, defaulting to: peoples_speech/clean
# reading metadata file: 0it [00:00, ?it/s]
# [{'id': '07282016HFUUforum_SLASH_07-28-2016_HFUUforum_DOT_mp3_00000.flac', 'audio': {'path': '07282016HFUUforum_SLASH_07-28-2016_HFUUforum_DOT_mp3_00000.flac', 'array': array([ 0.14205933,  0.20620728,  0.27151489, ...,  0.00402832,
#        -0.00628662, -0.01422119]), 'sampling_rate': 16000}, 'duration_ms': 14920, 'text': "i wanted this to share a few things but i'm going to not share as much as i wanted to share because we are starting late i'd like to get this thing going so we all get home at a decent hour this this election is very important to"}, {'id': '07282016HFUUforum_SLASH_07-28-2016_HFUUforum_DOT_mp3_00001.flac', 'audio': {'path': '07282016HFUUforum_SLASH_07-28-2016_HFUUforum_DOT_mp3_00001.flac', 'array': array([-0.01480103,  0.05319214, -0.0105896 , ..., -0.02996826,
#         0.06680298,  0.0071106 ]), 'sampling_rate': 16000}, 'duration_ms': 14530, 'text': "state we support agriculture to the tune of point four percent no way i made a mistake this year they lowered it from point four percent to point three eight percent and in the same breath they're saying food"}]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# reading metadata file: 0it [00:00, ?it/s]
# actual text: i wanted this to share a few things but i'm going to not share as much as i wanted to share because we are starting late i'd like to get this thing going so we all get home at a decent hour this this election is very important to
# prediction: {'text': 'ɑwɑɾ̃ɪɪʃɛɹfjuθɪŋzbʌɾɑmɡʌɾ̃ʌsnɑtʃɛɹʌzmʌtʃɪzɑwɑnɪdtɪʃɛɹbikʌzwiɑɹstɑɹɾɪleɪtaɪdlaɪktɪɡɛtðɪsθɪŋɡoʊɛnsʌʊwiɡɔlɡɛhoʊmɛɾɪðisʌnhaʊɹ̩ʌmðɪsðɪsʌlɛkʃɪnɪzʌmvɛɹiɪmpɔʊɹʔn̩tu'}
# actual text: state we support agriculture to the tune of point four percent no way i made a mistake this year they lowered it from point four percent to point three eight percent and in the same breath they're saying food
# prediction: {'text': 'steɪwisʌpoʊɹɾæɡɹ̩kʌltʃɹ̩tɪðɪtunʌvpɔɪtfɔɹpɹ̩sɛoʊnoʊwɪaɪmeɪɾɛmʌsteɪkðɪʃjiɹðeɪloʊɹ̩ɾɪtfɹ̩mpɔɪnfɔɹpɹ̩sɛnttʌpɔɪntθɹieɪpɹ̩sɛnæɾ̃ɪnðɪseɪmbɹɛðɛɹseɪɪmfuts'}
